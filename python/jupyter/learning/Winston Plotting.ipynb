# %%
using Winston, Random
# Out:
# Gtk-Message: 18:56:20.410: Failed to load module "canberra-gtk-module"
# Gtk-Message: 18:56:20.412: Failed to load module "canberra-gtk-module"

# %% [markdown]
# fix the random seed so we have reproducible results

# %%
Random.seed!(111)
# Out:
# TaskLocalRNG()

# %% [markdown]
# generate a plot

# %%
pl = plot(cumsum(rand(100) .- 0.5), "g", cumsum(rand(100) .- 0.5), "b")
# Out:
# FramedPlot(...)

# %% [markdown]
# display the plot

# %%
display(pl)
